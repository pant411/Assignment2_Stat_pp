# %%
setwd(getwd())

# %%
df <- read.csv("classroom.csv", sep=",", header=T, 
               fileEncoding="UTF-8-BOM")
attach(df)
df
# Out:
#    midterm  final
# 1  87.72727 88.33333
# 2  81.36364 86.83333
# 3  77.95455 67.50000
# 4  72.27273 56.00000
# 5  53.86364 51.00000
# 6  47.50000 45.16667
# 7  92.27273 89.33333
# 8  84.09091 72.83333
# 9  63.18182 46.66667
# 10 80.00000 71.50000
# 11 87.27273 80.33333
# 12 43.86364 55.66667
# 13 98.86364 95.50000
# 14 92.95455 90.16667
# 15 85.22727 80.66667
# 16 71.81818 62.16667
# 17 96.36364 83.16667
# 18 92.72727 92.00000
# 19 83.18182 78.50000
# 20 88.86364 84.33333
# 21 79.54545 64.83333
# 22 83.18182 85.33333
# 23 96.36364 72.66667
# 24 77.95455 74.66667
# 25 93.40909 85.66667
# 26 89.77273 92.83333
# 27 81.59091 59.00000
# 28 94.77273 83.16667
# 29 85.90909 78.50000
# 30 74.77273 83.00000
# 31 85.00000 80.83333
# 32 54.54545 46.66667
# 33 96.36364 93.66667
# 34 71.13636 76.00000
# 35 83.40909 65.33333
# 36 74.00000 70.00000
# 37 78.63636 69.50000
# 38 53.63636 61.66667
# 39 69.77273 45.83333
# 40 83.18182 85.66667
# 41 24.54545 21.66667
# 42 41.81818 45.16667
# ...

# %%
x <- midterm
y <- final

# %%
model <- lm(y ~ x)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.1937  -4.6742   0.0192   5.0606  13.6052
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.07712    5.32054   0.766    0.448
# x            0.87355    0.06785  12.874 2.39e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.177 on 43 degrees of freedom
# Multiple R-squared:  0.794,	Adjusted R-squared:  0.7892
# F-statistic: 165.7 on 1 and 43 DF,  p-value: 2.39e-16
