# %%
setwd(getwd())

# %%
Sys.setlocale("LC_CTYPE", "thai")
options(encoding="UTF-8")
# Out:
# [1] "Thai_Thailand.874"

# %%
library("xlsx")

# %%
#df <- read.csv("cars.csv", sep=",", header=T, fileEncoding="UTF-8-BOM")
df1 <- read.xlsx('assignment2_regression_govt_spending.xlsx',sheetIndex="side", header=TRUE)
attach(df1)
df1
# Out:
#    ปี   การป้องกันประเทศ การรักษาความสงบภายใน การเศรษฐกิจ การสาธารณสุข
# 1  2547  74106.0          65171.0             282325.2     83650.3
# 2  2548  78052.8          66727.2             296571.2     89163.7
# 3  2549  85107.6          77857.1             339783.5    101040.5
# 4  2550 114696.2          87631.5             332282.9    148704.5
# 5  2551 141265.8          93033.4             321879.7    153825.4
# 6  2552 168231.8         116762.4             341177.7    169633.2
# 7  2553 154274.8         111453.9             246328.7    178852.7
# 8  2554 168318.8         125306.3             429338.6    208093.4
# 9  2555 167444.3         132240.6             421238.7    220411.3
# 10 2556 177664.8         144384.7             470002.1    254793.5
# 11 2557 182149.7         149141.8             530060.5    252996.3
# 12 2558 191640.0         157365.5             545023.1    261113.1
# 13 2559 205375.8         175077.4             568481.6    274231.2
# ...

# %%
df2 <- read.xlsx('assignment2_regression_govt_spending.xlsx',sheetIndex="budget", header=TRUE)
attach(df2)
df2
# Out:
# The following object is masked from df1 (pos = 3):
#
#     ปี
#    ปี   งบกลาง   สำนักนายกรัฐมนตรี กระทรวงกลาโหม กระทรวงการคลัง
# 1  2547 130325.7  7437.524          78551.32     131532.4
# 2  2548 200190.0  9465.828          81241.39     140176.6
# 3  2549 256220.0 15188.506          85936.12     144371.5
# 4  2550 197650.7 14395.708         115024.01     172907.1
# 5  2551 242774.6 13579.665         143518.90     180496.6
# 6  2552 240940.6 25577.283         170157.39     202380.3
# 7  2553 215006.8 22909.851         154032.48     215709.7
# 8  2554 265763.0 24358.812         168501.83     208895.9
# 9  2555 422211.1 22123.700         168667.40     191415.1
# 10 2556 319864.0 25246.800         180491.50     180707.9
# 11 2557 343131.0 32160.000         183820.00     228796.6
# 12 2558 375708.1 33417.600         192949.10     185852.2
# 13 2559 422721.4 36001.300         206461.30     199174.1
# 14 2560 406016.0 35412.300         213449.90     217713.6
# ...

# %%
x1 <- กระทรวงยุติธรรม
x2 <- กระทรวงสาธารณสุข
x3 <- กระทรวงคมนาคม
x4 <- กระทรวงเกษตรเเละสหกรณ์
x5 <- กระทรวงมหาดไทย
y <- การเศรษฐกิจ

# %%
model <- lm(y ~ x1+x2+x3+x4+x5)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -47135 -17257  -7942  22832  41671
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 22782.1105 79396.0267   0.287   0.7795
# x1              2.6204    13.9238   0.188   0.8542
# x2             -1.9732     2.2809  -0.865   0.4055
# x3              1.5810     0.8071   1.959   0.0759 .
# x4              1.8289     2.0182   0.906   0.3842
# x5              0.9969     0.4114   2.423   0.0338 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 32850 on 11 degrees of freedom
# Multiple R-squared:  0.9611,	Adjusted R-squared:  0.9435
# F-statistic: 54.42 on 5 and 11 DF,  p-value: 2.188e-07

# %%
x1 <- กระทรวงการคลัง
x2 <- กระทรวงการต่างประเทศ
x3 <- กระทรวงอุตสาหกรรม
x4 <- กระทรวงการท่องเที่ยวและกีฬา
x5 <- กระทรวงคมนาคม
y <- การเศรษฐกิจ

# %%
model <- lm(y ~ x1+x2+x3+x4+x5)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3 + x4 + x5)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -46436 -12842  -6136  17747  40662
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 84386.2195 77274.5500   1.092   0.2982
# x1             -0.6781     0.5033  -1.347   0.2050
# x2             14.6810    21.2905   0.690   0.5048
# x3              7.9265    20.5929   0.385   0.7076
# x4              8.3785     4.1174   2.035   0.0667 .
# x5              2.8251     0.4148   6.811 2.91e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 30780 on 11 degrees of freedom
# Multiple R-squared:  0.9659,	Adjusted R-squared:  0.9504
# F-statistic: 62.27 on 5 and 11 DF,  p-value: 1.077e-07

# %%
x1 <- กระทรวงการท่องเที่ยวและกีฬา
x2 <- กระทรวงคมนาคม
y <- การเศรษฐกิจ

# %%
model <- lm(y ~ x1+x2)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x1 + x2)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -47443 -18185    489  19300  57174
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.039e+05  2.074e+04   5.009 0.000191 ***
# x1          1.021e+01  2.379e+00   4.290 0.000748 ***
# x2          2.736e+00  1.759e-01  15.552 3.15e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 29600 on 14 degrees of freedom
# Multiple R-squared:  0.9598,	Adjusted R-squared:  0.9541
# F-statistic: 167.3 on 2 and 14 DF,  p-value: 1.684e-10
